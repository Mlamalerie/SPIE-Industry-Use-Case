# %%
from src.data.others import get_dict_parents_enfants
get_dict_parents_enfants()
# Out:
# {'PL1111': ['M120-5-1104',
#   'A120-4-639',
#   'M160-5-246',
#   'M120-5-287',
#   'M170-6-713',
#   'A25-1-587',
#   'M120-5-893',
#   'A85-3-562',
#   'A50-3-248',
#   'A85-3-583',
#   'A110-5-222',
#   'M180-5-43',
#   'M160-5-136',
#   'A30-2-739',
#   'A100-3-13',
#   'M250-5-71',
#   'A110-5-165',
#   'A50-3-72',
#   'A100-3-750',
#   'M65-3-473',
#   'A15-1-646',
#   'A50-2-376',
#   'A50-3-125',
#   'M150-4-729',
#   'M120-5-431',
#   'A30-2-849',
#   'A110-5-343',
#   'A30-2-216',
#   'A110-5-77',
#   'A100-3-175',
#   'M65-3-125',
#   'M140-5-1138',
#   'M120-5-1025',
#   'M200-6-281',
#   'M140-5-659',
#   'M170-6-575',
#   'A15-1-362',
#   'M100-3-473',
#   'M135-3-246',
#   'M140-5-151',
#   'M140-5-195',
#   'M140-5-138',
#   'M50-2-138',
#   'A120-4-50',
#   'A15-1-634',
#   'M200-6-14',
#   'M90-4-624',
#   'M65-3-403',
#   'M160-5-20',
#   'M150-4-790',
#   'A30-2-333',
#   'A50-3-264',
#   'M100-3-684',
#   'A50-2-382',
#   'M100-3-853',
#   'M140-5-327',
# ...

# %%
from src.data.consommation import ConsommationDataManager
cdm = ConsommationDataManager()
cdm.logements_names
# Out:
# ['A100-3-1',
#  'A100-3-100',
#  'A100-3-102',
#  'A100-3-105',
#  'A100-3-106',
#  'A100-3-107',
#  'A100-3-108',
#  'A100-3-109',
#  'A100-3-111',
#  'A100-3-112',
#  'A100-3-113',
#  'A100-3-115',
#  'A100-3-117',
#  'A100-3-118',
#  'A100-3-119',
#  'A100-3-120',
#  'A100-3-121',
#  'A100-3-122',
#  'A100-3-123',
#  'A100-3-125',
#  'A100-3-126',
#  'A100-3-127',
#  'A100-3-129',
#  'A100-3-13',
#  'A100-3-130',
#  'A100-3-131',
#  'A100-3-132',
#  'A100-3-133',
#  'A100-3-134',
#  'A100-3-135',
#  'A100-3-137',
#  'A100-3-138',
#  'A100-3-139',
#  'A100-3-140',
#  'A100-3-141',
#  'A100-3-142',
#  'A100-3-146',
#  'A100-3-148',
#  'A100-3-149',
#  'A100-3-15',
#  'A100-3-151',
#  'A100-3-152',
#  'A100-3-153',
#  'A100-3-154',
#  'A100-3-155',
#  'A100-3-156',
#  'A100-3-158',
#  'A100-3-159',
#  'A100-3-16',
#  'A100-3-160',
#  'A100-3-161',
#  'A100-3-164',
#  'A100-3-166',
#  'A100-3-167',
#  'A100-3-168',
#  'A100-3-169',
#  'A100-3-17',
#  'A100-3-170',
#  'A100-3-173',
# ...

# %%
cdm.logements_names
# Out:
# ['A100-3-1',
#  'A100-3-100',
#  'A100-3-102',
#  'A100-3-105',
#  'A100-3-106',
#  'A100-3-107',
#  'A100-3-108',
#  'A100-3-109',
#  'A100-3-111',
#  'A100-3-112',
#  'A100-3-113',
#  'A100-3-115',
#  'A100-3-117',
#  'A100-3-118',
#  'A100-3-119',
#  'A100-3-120',
#  'A100-3-121',
#  'A100-3-122',
#  'A100-3-123',
#  'A100-3-125',
#  'A100-3-126',
#  'A100-3-127',
#  'A100-3-129',
#  'A100-3-13',
#  'A100-3-130',
#  'A100-3-131',
#  'A100-3-132',
#  'A100-3-133',
#  'A100-3-134',
#  'A100-3-135',
#  'A100-3-137',
#  'A100-3-138',
#  'A100-3-139',
#  'A100-3-140',
#  'A100-3-141',
#  'A100-3-142',
#  'A100-3-146',
#  'A100-3-148',
#  'A100-3-149',
#  'A100-3-15',
#  'A100-3-151',
#  'A100-3-152',
#  'A100-3-153',
#  'A100-3-154',
#  'A100-3-155',
#  'A100-3-156',
#  'A100-3-158',
#  'A100-3-159',
#  'A100-3-16',
#  'A100-3-160',
#  'A100-3-161',
#  'A100-3-164',
#  'A100-3-166',
#  'A100-3-167',
#  'A100-3-168',
#  'A100-3-169',
#  'A100-3-17',
#  'A100-3-170',
#  'A100-3-173',
# ...

# %%
cdm.load_all_dfs_conso()
# Out:
# Loading all...
# Loading: [------------------> ] 95%

# %%
cdm.logements_types
# Out:
# ['A100-3',
#  'A120-4',
#  'A130-4',
#  'A15-1',
#  'A25-1',
#  'A30-2',
#  'A50-2',
#  'A50-3',
#  'M100-3',
#  'M110-4',
#  'M120-5',
#  'M135-3',
#  'M140-5',
#  'M150-4',
#  'M160-5',
#  'M200-6',
#  'M50-2',
#  'M65-3',
#  'M80-2',
#  'M85-3']

# %%
dfs = cdm.get_dfs_conso_by_logement_type("A15-1")
dfs.keys()
# Out:
# dict_keys(['A15-1-10', 'A15-1-100', 'A15-1-101', 'A15-1-103', 'A15-1-104', 'A15-1-105', 'A15-1-106', 'A15-1-108', 'A15-1-11', 'A15-1-110', 'A15-1-112', 'A15-1-114', 'A15-1-115', 'A15-1-116', 'A15-1-117', 'A15-1-119', 'A15-1-12', 'A15-1-120', 'A15-1-121', 'A15-1-122', 'A15-1-123', 'A15-1-125', 'A15-1-127', 'A15-1-128', 'A15-1-129', 'A15-1-13', 'A15-1-130', 'A15-1-131', 'A15-1-133', 'A15-1-134', 'A15-1-136', 'A15-1-137', 'A15-1-138', 'A15-1-139', 'A15-1-14', 'A15-1-140', 'A15-1-141', 'A15-1-144', 'A15-1-145', 'A15-1-146', 'A15-1-147', 'A15-1-148', 'A15-1-149', 'A15-1-15', 'A15-1-150', 'A15-1-151', 'A15-1-152', 'A15-1-153', 'A15-1-156', 'A15-1-158', 'A15-1-159', 'A15-1-16', 'A15-1-160', 'A15-1-161', 'A15-1-162', 'A15-1-164', 'A15-1-165', 'A15-1-168', 'A15-1-169', 'A15-1-17', 'A15-1-170', 'A15-1-171', 'A15-1-172', 'A15-1-18', 'A15-1-19', 'A15-1-2', 'A15-1-22', 'A15-1-25', 'A15-1-26', 'A15-1-275', 'A15-1-29', 'A15-1-3', 'A15-1-30', 'A15-1-307', 'A15-1-31', 'A15-1-317', 'A15-1-32', 'A15-1-
# ...

# %%
from src.data.equipements import EquipementsDataManager

eqm = EquipementsDataManager()
# Out:
# {'puissance': '3',
#  'tps_cycle': '6',
#  'amperage': '15',
#  'hr_debut': 1,
#  'hr_max': nan,
#  'sequensable': 1}

# %%
eqm.caracteristiques_equipements['Mc5-CE']
