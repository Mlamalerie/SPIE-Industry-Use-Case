# %%
import sys
sys.path.append('..')
from data.datamanagers import ConsommationDataManager
import pandas as pd
import matplotlib.pyplot as plt

# plot exemple
plt.plot([1, 2, 3, 4])
plt.show()
# %%

# %%
cdm = ConsommationDataManager()
df = cdm.get_df_conso_by_logement_name("A15-1-4")
df.loc["2020":"2021"].shape
# Out:
# (731, 49)

# %%
df.loc["2022","5:00"].plot()

plt.legend()

plt.show()
